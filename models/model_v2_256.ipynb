# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

train_dir = "../데이터셋/한국인 감정인식을 위한 복합 영상/최종데이터셋/train"
val_dir = "../데이터셋/한국인 감정인식을 위한 복합 영상/최종데이터셋/val"
test_dir = "../데이터셋/한국인 감정인식을 위한 복합 영상/최종데이터셋/test"

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale')

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale')
# Out:
# Found 51328 images belonging to 7 classes.
# Found 10999 images belonging to 7 classes.
# Found 10999 images belonging to 7 classes.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential


model = Sequential()

model.add(Conv2D(64,(3,3), padding='same', input_shape=(256, 256,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))


model.add(Dense(7, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 64)      640
#
#  batch_normalization (BatchN  (None, 256, 256, 64)     256
#  ormalization)
#
#  activation (Activation)     (None, 256, 256, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 64)     0
#  )
#
#  dropout (Dropout)           (None, 128, 128, 64)      0
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 128)     204928
#
#  batch_normalization_1 (Batc  (None, 128, 128, 128)    512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 128, 128, 128)     0
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 64, 64, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 512)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 512)       0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 512)       2359808
#
#  batch_normalization_3 (Batc  (None, 32, 32, 512)      2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 512)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 512)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 512)       0
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 256)               33554688
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 36,853,511
# Trainable params: 36,849,543
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint_path = "saved_models/v2_256_best_model.hdf5"
checkpoint_cb = ModelCheckpoint(checkpoint_path, verbose=1, save_best_only=True,monitor='val_loss')
early_stop_cb = EarlyStopping(patience=15,restore_best_weights=True)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=300,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
    callbacks=[checkpoint_cb,early_stop_cb])
# Out:
# Epoch 1/300
# 1604/1604 [==============================] - ETA: 0s - loss: 1.3510 - accuracy: 0.4945
# Epoch 1: val_loss improved from inf to 1.18562, saving model to saved_models\v2_256_best_model.hdf5
# 1604/1604 [==============================] - 552s 331ms/step - loss: 1.3510 - accuracy: 0.4945 - val_loss: 1.1856 - val_accuracy: 0.5554
# Epoch 2/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.9748 - accuracy: 0.6397
# Epoch 2: val_loss improved from 1.18562 to 0.99463, saving model to saved_models\v2_256_best_model.hdf5
# 1604/1604 [==============================] - 590s 368ms/step - loss: 0.9748 - accuracy: 0.6397 - val_loss: 0.9946 - val_accuracy: 0.6272
# Epoch 3/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.8427 - accuracy: 0.6893
# Epoch 3: val_loss improved from 0.99463 to 0.87778, saving model to saved_models\v2_256_best_model.hdf5
# 1604/1604 [==============================] - 612s 382ms/step - loss: 0.8427 - accuracy: 0.6893 - val_loss: 0.8778 - val_accuracy: 0.6690
# Epoch 4/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.7253 - accuracy: 0.7350
# Epoch 4: val_loss did not improve from 0.87778
# 1604/1604 [==============================] - 657s 409ms/step - loss: 0.7253 - accuracy: 0.7350 - val_loss: 1.0955 - val_accuracy: 0.6085
# Epoch 5/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.6232 - accuracy: 0.7732
# Epoch 5: val_loss improved from 0.87778 to 0.72010, saving model to saved_models\v2_256_best_model.hdf5
# 1604/1604 [==============================] - 589s 367ms/step - loss: 0.6232 - accuracy: 0.7732 - val_loss: 0.7201 - val_accuracy: 0.7354
# Epoch 6/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.5235 - accuracy: 0.8067
# Epoch 6: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 592s 369ms/step - loss: 0.5235 - accuracy: 0.8067 - val_loss: 0.8554 - val_accuracy: 0.6970
# Epoch 7/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.8400
# Epoch 7: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 614s 382ms/step - loss: 0.4375 - accuracy: 0.8400 - val_loss: 0.8543 - val_accuracy: 0.7112
# Epoch 8/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.8692
# Epoch 8: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 576s 359ms/step - loss: 0.3596 - accuracy: 0.8692 - val_loss: 0.7703 - val_accuracy: 0.7309
# Epoch 9/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.2986 - accuracy: 0.8914
# Epoch 9: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 606s 378ms/step - loss: 0.2986 - accuracy: 0.8914 - val_loss: 0.8425 - val_accuracy: 0.7233
# Epoch 10/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9105
# Epoch 10: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 575s 358ms/step - loss: 0.2492 - accuracy: 0.9105 - val_loss: 0.9069 - val_accuracy: 0.7327
# Epoch 11/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9239
# Epoch 11: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 588s 366ms/step - loss: 0.2167 - accuracy: 0.9239 - val_loss: 0.9314 - val_accuracy: 0.7461
# Epoch 12/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9337
# Epoch 12: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 575s 358ms/step - loss: 0.1852 - accuracy: 0.9337 - val_loss: 0.8539 - val_accuracy: 0.7518
# Epoch 13/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9403
# Epoch 13: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 560s 349ms/step - loss: 0.1687 - accuracy: 0.9403 - val_loss: 0.8853 - val_accuracy: 0.7683
# Epoch 14/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9494
# Epoch 14: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 567s 353ms/step - loss: 0.1457 - accuracy: 0.9494 - val_loss: 0.9338 - val_accuracy: 0.7401
# Epoch 15/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9534
# Epoch 15: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 575s 358ms/step - loss: 0.1355 - accuracy: 0.9534 - val_loss: 1.0251 - val_accuracy: 0.7297
# Epoch 16/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9537
# Epoch 16: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 559s 349ms/step - loss: 0.1315 - accuracy: 0.9537 - val_loss: 1.0124 - val_accuracy: 0.7598
# Epoch 17/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9608
# Epoch 17: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 496s 309ms/step - loss: 0.1125 - accuracy: 0.9608 - val_loss: 1.0079 - val_accuracy: 0.7399
# Epoch 18/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9627
# Epoch 18: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 497s 310ms/step - loss: 0.1107 - accuracy: 0.9627 - val_loss: 0.9467 - val_accuracy: 0.7283
# Epoch 19/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9651
# Epoch 19: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 519s 324ms/step - loss: 0.1024 - accuracy: 0.9651 - val_loss: 1.0401 - val_accuracy: 0.7399
# Epoch 20/300
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9673
# Epoch 20: val_loss did not improve from 0.72010
# 1604/1604 [==============================] - 520s 324ms/step - loss: 0.0951 - accuracy: 0.9673 - val_loss: 1.2856 - val_accuracy: 0.6826

# %%
model.evaluate(test_generator)
# Out:
# 344/344 [==============================] - 32s 93ms/step - loss: 0.7241 - accuracy: 0.7359
# [0.7240869402885437, 0.7358850836753845]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.xlabel("epoch")
plt.ylabel("loss")

plt.show()

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.xlabel("epoch")
plt.ylabel("accuracy")

plt.show()
